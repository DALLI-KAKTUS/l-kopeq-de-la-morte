# %%
# MANİTAYLA KIRMIZI ŞARAP KALİTESİ SINIFLANDIRMA
#--------------------------------------------------------------#
#                                                              #
#  berke: bugnü bütün zamanıma mal olduu içni doaya kırgınm :( #
#  doa: miuv <3                                                #
#                                                              #
#--------------------------------------------------------------#
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import missingno as msno
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import LocalOutlierFactor
from sklearn.model_selection import GridSearchCV, train_test_split, learning_curve
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score
from sklearn.impute import KNNImputer
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA
from sklearn.feature_selection import RFECV

from xgboost import XGBClassifier
#from catboost import CatBoostClassifier
#from lightgbm import LGBMClassifier

# %%
df=pd.read_csv('./winequality-red.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.isnull().sum() # boş veri yok
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.shape
# Out:
# (1599, 12)

# %%
df[df.duplicated(keep=False)] # keep=False ile hangi öğelerin aynı olduğunu listele
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 4               7.4             0.700         0.00             1.9      0.076
# 9               7.5             0.500         0.36             6.1      0.071
# 11              7.5             0.500         0.36             6.1      0.071
# 22              7.9             0.430         0.21             1.6      0.106
# ...             ...               ...          ...             ...        ...
# 1567            7.2             0.695         0.13             2.0      0.076
# 1579            6.2             0.560         0.09             1.7      0.053
# 1581            6.2             0.560         0.09             1.7      0.053
# 1592            6.3             0.510         0.13             2.3      0.076
# 1596            6.3             0.510         0.13             2.3      0.076
#
# ...

# %%
df = df.drop_duplicates()
df #silinen öğelerin dizinleri yanlış sıralandı
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df = df.reset_index(drop=True)#dizinleri resetle
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1354            6.8             0.620         0.08             1.9      0.068
# 1355            6.2             0.600         0.08             2.0      0.090
# 1356            5.9             0.550         0.10             2.2      0.062
# 1357            5.9             0.645         0.12             2.0      0.075
# 1358            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# ## başlangıçta 1600 öğe vardı
# ## 460 adet tekrarlayan öğeyi sildik
# ## 1359 öğe kaldı

# %%
bar = df['quality'].value_counts()
plt.bar(bar.index, bar.values)
plt.show()

# %%
plt.subplots()
plt.pie(bar.values,labels=bar.index, autopct='%1.1f%%', radius=1.5)
# Out:
# ([<matplotlib.patches.Wedge at 0x7af9cef9d610>,
# ...
#  [Text(0.3873169579987751, 1.6038969960837808, '5'),
#   Text(-1.1927241582470043, -1.1401355543679776, '6'),
#   Text(1.2006032254273833, -1.1318356307756725, '7'),
#   Text(1.599781060429324, -0.40398088901781964, '4'),
#   Text(1.6439681379686082, -0.14095659382954662, '8'),
#   Text(1.6495591655489683, -0.03813868578480475, '3')],
#  [Text(0.2112637952720591, 0.8748529069547895, '42.5%'),
#   Text(-0.650576813589275, -0.6218921205643514, '39.4%'),
#   Text(0.6548744865967544, -0.6173648895140031, '12.3%'),
#   Text(0.8726078511432674, -0.22035321219153794, '3.9%'),
#   Text(0.8967098934374225, -0.07688541481611631, '1.3%'),
#   Text(0.8997595448448916, -0.020802919518984407, '0.7%')])

# %%
for i in df.columns:
    sns.displot(df,x=i,kde=True)

# %%
for i in df.columns:
    sns.violinplot(data=df, y=i)
    plt.figure()

# %%
plt.subplots(figsize = (10 ,8))
mask= np.triu(np.ones_like(df.corr(), dtype= bool))#üst matrix'i silmek için maske hazırlıyoruz
sns.heatmap(df.corr().mask(mask),square = True, linewidths = .5,annot=True,linewidth=2, linecolor="pink")
# Out:
# <Axes: >

# %%
df.corr().abs().mask(mask)
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity                   NaN               NaN          NaN
# volatile acidity           0.255124               NaN          NaN
# citric acid                0.667437          0.551248          NaN
# residual sugar             0.111025          0.002449     0.143892
# chlorides                  0.085886          0.055154     0.210195
# free sulfur dioxide        0.140580          0.020945     0.048004
# total sulfur dioxide       0.103777          0.071701     0.047358
# density                    0.670195          0.023943     0.357962
# pH                         0.686685          0.247111     0.550310
# sulphates                  0.190269          0.256948     0.326062
# alcohol                    0.061596          0.197812     0.105108
# quality                    0.119024          0.395214     0.228057
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
high_corr=[c for c in df.corr().abs().mask(mask).columns if any(df.corr().abs().mask(mask)[c]>0.65 )] #|0.65|'den büyük korelasyonu olan colonları listele

# %%
#df.drop(high_corr,axis=1) #şimdilik herhangi bir kolon silmiyoryuz çünkü mantıklı gelmedi

# %%
for i in df.drop(["quality"],axis=1).columns:
    sns.boxplot(data=df, y=i,x=df['quality'])
    plt.figure()

# %%
for i in df.drop(["quality"],axis=1).columns:
    sns.scatterplot(data=df, y=i,x=df['quality'])
    plt.figure()

# %%
obeks = pd.DataFrame()
for i in np.sort(df['quality'].unique()):
    obeks[i] = df['quality'].apply(lambda x: 1 if x==i else 0)
df[obeks[3]==1]['fixed acidity']
# Out:
# 400     11.6
# 450     10.4
# 597      7.4
# 718     10.4
# 771      8.3
# 1106     7.6
# 1165     6.8
# 1245     7.3
# 1253     7.1
# 1276     6.7
# Name: fixed acidity, dtype: float64

# %% [markdown]
# # Alkol oranlarına göre sınıflandırma
# - al<10 az alkollü
# - 10<al<13 orta alkollü
# - 13<al lö kopeq de la morte

# %%
df.loc[df['alcohol'] < 13  , 'kafası']='var'
df.loc[df['alcohol'] <= 10 , 'kafası']='yok'
df.loc[df['alcohol'] >= 13 , 'kafası']='sağlam'

# %%
df[df['alcohol'] == 10]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 6               7.3             0.650         0.00             1.2      0.065
# 54              7.8             0.590         0.18             2.3      0.076
# 105             8.3             0.540         0.28             1.9      0.077
# 130             5.8             0.680         0.02             1.8      0.087
# 143             7.8             0.530         0.04             1.7      0.076
# ...             ...               ...          ...             ...        ...
# 1190            7.2             0.330         0.33             1.7      0.061
# 1239            6.2             0.785         0.00             2.1      0.060
# 1243            7.3             0.480         0.32             2.1      0.062
# 1267            6.4             0.310         0.09             1.4      0.066
# 1292            6.0             0.420         0.19             2.0      0.075
#
# ...
